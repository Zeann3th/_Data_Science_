# %% [markdown]
# # Introduction to Matplotlib

# %% [markdown]
# ### 1. Importing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Preparing Data

# %%
cities = pd.read_csv("../Databases/california_cities.csv")
cities
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          NaN
# 3             3       Albany  37.886944 -122.297778          NaN
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %%
# Extract Latitude & Longtitude
lat, long = cities['latd'], cities['longd']
population, area =  cities['population_total'], cities['area_total_km2']
plt.figure(figsize = (8, 6))

# Plot using Pyplot API
plt.scatter(long, lat, c = np.log10(population), s = area, cmap = 'viridis', linewidth = 0, alpha = 0.5)

# Modifications
plt.colorbar(label = 'log$_{10}$(population)')
plt.clim(3,7)
plt.axis("equal")
plt.xlabel("Longtitude")
plt.ylabel("Latitude")
plt.title("California cities: Population and Area Distribution")
plt.legend();
# Create a legend for cities size
area_range = [50, 100, 300, 500]
for area in area_range:
    plt.scatter([], [], s = area, label = str(area) + 'km$^2$', c = 'green', alpha = 0.4)
plt.legend(labelspacing = 1, title = "City Area");
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
